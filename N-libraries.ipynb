# %% [markdown]
# # Numpy libraries

# %% [raw]
# Array in Numpy: general purpose array-processing package. it provide a high performance multimedia array object, and tools for working woth arrays. its is the fundamental package for scientific computing with python.

# %%
## Array in numpy
import numpy as np    # np is alias of numpy library
a = np.array([1,2,4,5])   # this is the one dimancinal array
print(a)
# Out:
# [1 2 4 5]

# %%
b = np.array([2,4,6,8])
print(b)
type(b)
# Out:
# [2 4 6 8]
# numpy.ndarray

# %%
# Two dimension array
row1 = [2,4,6,8]
row2 = [1,3,5,7]
row3 = [1,3,4,6]
arr = np.array(row1)
arr1 = np.array([row1,row2,row3])
print(arr1)
arr.shape
# Out:
# [[2 4 6 8]
#  [1 3 5 7]
#  [1 3 4 6]]
# (4,)

# %%
# Indexing in array
print(arr)
# Out:
# [2 4 6 8]

# %%
print(arr[0])
print(arr[1])
# Out:
# 2
# 4

# %%
arr
# Out:
# array([2, 4, 6, 8])

# %%
arr[:-1]
# Out:
# array([2, 4, 6])

# %%
print(arr[::-1])
print(arr[::-2])
print(arr1)
# Out:
# [8 6 4 2]
# [8 4]
# [[2 4 6 8]
#  [1 3 5 7]
#  [1 3 4 6]]

# %%
arr1[:,1]   # all row of 1 column
arr1[1:,1]
arr1[1:,0]
# Out:
# array([1, 1])

# %%
 arr1[:,2]
arr1
# Out:
# array([[2, 4, 6, 8],
#        [1, 3, 5, 7],
#        [1, 3, 4, 6]])

# %%
arr1[1:,2:4]
# Out:
# array([[5, 7],
#        [4, 6]])

# %%
arr1[0:,2:4]
# Out:
# array([[6, 8],
#        [5, 7],
#        [4, 6]])

# %%
## EDA point of view
arr[arr<6]
# Out:
# array([2, 4])

# %%
arr1.shape
# Out:
# (3, 4)

# %%
## reshape the array
arr1.reshape(4,3)
# Out:
# array([[2, 4, 6],
#        [8, 1, 3],
#        [5, 7, 1],
#        [3, 4, 6]])

# %%
np.arange(0,11,2).reshape(3,1,2)
# Out:
# array([[[ 0,  2]],
#
#        [[ 4,  6]],
#
#        [[ 8, 10]]])

# %%
print(arr)
print(arr * arr)
# Out:
# [2 4 6 8]
# [ 4 16 36 64]

# %%
np.zeros(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 np.zeros(3,4)
#
# TypeError: Cannot interpret '4' as a data type

# %%
np.random.randint(10,50,4)
# Out:
# array([33, 41, 37, 15], dtype=int32)

# %%
np.random.random_sample((4,7))
# Out:
# array([[0.82509982, 0.11287838, 0.80150715, 0.24231688, 0.52037493,
#         0.12936404, 0.21766089],
#        [0.69187266, 0.60128516, 0.98456708, 0.07832039, 0.59259287,
#         0.96937375, 0.75285782],
#        [0.21213051, 0.00819505, 0.36408141, 0.74116501, 0.63393937,
#         0.3003892 , 0.39326193],
#        [0.5559123 , 0.17344149, 0.4424854 , 0.23396666, 0.0394092 ,
#         0.30734194, 0.45460773]])
