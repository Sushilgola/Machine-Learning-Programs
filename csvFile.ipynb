# %% [markdown]
# 1. StringIO
# 2. Pandas read_csv

# %%
## Reading different data source with help of pandas
from io import StringIO   # StringIO help to read csv file
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\sushi\Downloads/dataset.csv")
df.head()
# Out:
#    EmployeeID    Name Department  Age Gender  Salary  ExperienceYears    City  \
# 0         101    Amit         IT   25      M   40000                2   Delhi
# 1         102  Suresh         HR   30      M   35000                5  Mumbai
# 2         103    Ravi         IT   28      M   45000                3   Delhi
# 3         104    Neha    Finance   35      F   60000               10    Pune
# 4         105   Pooja         HR   26      F   38000                4  Mumbai
#
#    JoiningYear
# 0         2022
# 1         2019
# 2         2021
# 3         2015
# 4         2020

# %%
StringIO(df)   # this is data Frame not string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 StringIO(df)
#
# TypeError: initial_value must be str or None, not DataFrame

# %%
data = ('col1,col2,col3\n'     # This is str type data that work in csv file
        'x,y,1\n'
        'a,b,2\n'
        'c,d,3\n'
       'p,q,4')
type(data)
# Out:
# str

# %%
# In memory file format object
StringIO(data)

# %%
pd.read_csv(StringIO(data))
# Out:
#   col1 col2  col3
# 0    x    y     1
# 1    a    b     2
# 2    c    d     3
# 3    p    q     4

# %%
pd.read_csv(StringIO(data),usecols=['col1', 'col2', 'col3'])
# Out:
#   col1 col2  col3
# 0    x    y     1
# 1    a    b     2
# 2    c    d     3
# 3    p    q     4

# %%
df.to_csv(r"C:\Users\sushi\Downloads/dataset.csv",index = False)  # index method remove the index in file

# %%
pd.read_csv(r"C:\Users\sushi\Downloads/dataset.csv")
# Out:
#    EmployeeID    Name Department  Age Gender  Salary  ExperienceYears  \
# 0         101    Amit         IT   25      M   40000                2
# 1         102  Suresh         HR   30      M   35000                5
# 2         103    Ravi         IT   28      M   45000                3
# 3         104    Neha    Finance   35      F   60000               10
# 4         105   Pooja         HR   26      F   38000                4
# 5         106   Ankit         IT   29      M   50000                6
# 6         107   Rahul  Marketing   32      M   42000                7
# 7         108   Kiran    Finance   40      M   70000               15
# 8         109   Sneha  Marketing   27      F   39000                3
# 9         110   Vikas         IT   31      M   52000                8
#
#         City  JoiningYear
# 0      Delhi         2022
# 1     Mumbai         2019
# 2      Delhi         2021
# 3       Pune         2015
# 4     Mumbai         2020
# 5  Bangalore         2018
# ...

# %%
data = ('col1,col2,col3\n'     # This is str type data that work in csv file
        'x,y,1\n'
        'a,b,2\n'
        'c,d\n'
       'p')

# %%
pd.read_csv(StringIO(data))  # select nan value by default
# Out:
#   col1 col2  col3
# 0    x    y   1.0
# 1    a    b   2.0
# 2    c    d   NaN
# 3    p  NaN   NaN

# %%
df = pd.read_csv(StringIO(data),dtype = 'object')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      object
#  1   col2    3 non-null      object
#  2   col3    3 non-null      object
# dtypes: object(3)
# memory usage: 228.0+ bytes

# %%
data1 = ('a,b,c,d\n'
        '2,3,4,5\n'
        '1.2,3.4,4\n'
        '5,6,7')
type(data1)
pd.read_csv(StringIO(data1))
# Out:
#      a    b  c    d
# 0  2.0  3.0  4  5.0
# 1  1.2  3.4  4  NaN
# 2  5.0  6.0  7  NaN

# %%
df = pd.read_csv(StringIO(data),dtype = {'a':int,'b':float,'c':int})

# %%
df.info() 
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      object
#  1   col2    3 non-null      object
#  2   col3    2 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 228.0+ bytes
# col1     object
# col2     object
# col3    float64
# dtype: object

# %%
data = ('index,a,b,c\n'
        '2,apple,mango,4.56\n'
        '4,grapes,guava,5.78')
pd.read_csv(StringIO(data))
# Out:
#    index       a      b     c
# 0      2   apple  mango  4.56
# 1      4  grapes  guava  5.78

# %%
pd.read_csv(StringIO(data),usecols= ['a','b','c'],index_col=0)
# Out:
#             b     c
# a
# apple   mango  4.56
# grapes  guava  5.78

# %%
pd.read_csv('url')  # you can read any url data with help of csv reader
