# %% [markdown]
# # Work with json file type
# 1. read json(read_json)
# 2. To Json(to_json)
# 3. json Normalize

# %% [markdown]
# # Assignment - To check what type of data use in split method in json

# %%
data = '{"employee_name": "Sushil", "email": "sushil@gamil.com","profile": [{"title1":"AIML","title2":"Engineer"}]}'

# %%
import pandas as pd
from io import StringIO

# %%
type(data)
pd.read_json(StringIO(data))
# Out:
#   employee_name             email                                   profile
# 0        Sushil  sushil@gamil.com  {'title1': 'AIML', 'title2': 'Engineer'}

# %%
pd.read_json(StringIO(data),orient='records')  ## Usually focus on main data records
# Out:
#   employee_name             email                                   profile
# 0        Sushil  sushil@gamil.com  {'title1': 'AIML', 'title2': 'Engineer'}

# %%
pd.read_json(StringIO(data),orient='index')
# Out:
#                                                         0
# employee_name                                      Sushil
# email                                    sushil@gamil.com
# profile        [{'title1': 'AIML', 'title2': 'Engineer'}]

# %%
pd.read_json(StringIO(data),orient='values')
# Out:
#   employee_name             email                                   profile
# 0        Sushil  sushil@gamil.com  {'title1': 'AIML', 'title2': 'Engineer'}

# %%
dataf = pd.DataFrame([['a','b'],['c','d']],
                     index=['row1','row2'],
                     columns=['col1','col2'])

# %%
dataf
# Out:
#      col1 col2
# row1    a    b
# row2    c    d

# %%
dataf.to_json()
# Out:
# '{"col1":{"row1":"a","row2":"c"},"col2":{"row1":"b","row2":"d"}}'

# %%
dataf.to_json(orient='index')
# Out:
# '{"row1":{"col1":"a","col2":"b"},"row2":{"col1":"c","col2":"d"}}'

# %%
dataf.to_json(orient='columns')
# Out:
# '{"col1":{"row1":"a","row2":"c"},"col2":{"row1":"b","row2":"d"}}'

# %%
dataf.to_json(orient='records')
# Out:
# '[{"col1":"a","col2":"b"},{"col1":"c","col2":"d"}]'

# %%
dataf.to_json(orient='split') # split the data into row ,columns and values form
# Out:
# '{"columns":["col1","col2"],"index":["row1","row2"],"data":[["a","b"],["c","d"]]}'

# %%
dataf.to_json(orient='table')
# Out:
# '{"schema":{"fields":[{"name":"index","type":"string"},{"name":"col1","type":"string"},{"name":"col2","type":"string"}],"primaryKey":["index"],"pandas_version":"1.4.0"},"data":[{"index":"row1","col1":"a","col2":"b"},{"index":"row2","col1":"c","col2":"d"}]}'

# %%
schema = '{"schema":{"fields":[{"name":"index","type":"string"},{"name":"col1","type":"string"},{"name":"col2","type":"string"}],"primaryKey":["index"],"pandas_version":"1.4.0"},"data":[{"index":"row1","col1":"a","col2":"b"},{"index":"row2","col1":"c","col2":"d"}]}'

# %%
pd.read_json(StringIO(schema),orient='table')
# Out:
#      col1 col2
# row1    a    b
# row2    c    d

# %%
df = pd.read_csv(r'C:\Users\sushi\Downloads\iris/iris.data',header=None)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
jdata = df.to_json(orient='index')  # we can easily save on mongoDB Database

# %%
type(jdata)
jdata
# Out:
# '{"0":{"0":5.1,"1":3.5,"2":1.4,"3":0.2,"4":"Iris-setosa"},"1":{"0":4.9,"1":3.0,"2":1.4,"3":0.2,"4":"Iris-setosa"},"2":{"0":4.7,"1":3.2,"2":1.3,"3":0.2,"4":"Iris-setosa"},"3":{"0":4.6,"1":3.1,"2":1.5,"3":0.2,"4":"Iris-setosa"},"4":{"0":5.0,"1":3.6,"2":1.4,"3":0.2,"4":"Iris-setosa"},"5":{"0":5.4,"1":3.9,"2":1.7,"3":0.4,"4":"Iris-setosa"},"6":{"0":4.6,"1":3.4,"2":1.4,"3":0.3,"4":"Iris-setosa"},"7":{"0":5.0,"1":3.4,"2":1.5,"3":0.2,"4":"Iris-setosa"},"8":{"0":4.4,"1":2.9,"2":1.4,"3":0.2,"4":"Iris-setosa"},"9":{"0":4.9,"1":3.1,"2":1.5,"3":0.1,"4":"Iris-setosa"},"10":{"0":5.4,"1":3.7,"2":1.5,"3":0.2,"4":"Iris-setosa"},"11":{"0":4.8,"1":3.4,"2":1.6,"3":0.2,"4":"Iris-setosa"},"12":{"0":4.8,"1":3.0,"2":1.4,"3":0.1,"4":"Iris-setosa"},"13":{"0":4.3,"1":3.0,"2":1.1,"3":0.1,"4":"Iris-setosa"},"14":{"0":5.8,"1":4.0,"2":1.2,"3":0.2,"4":"Iris-setosa"},"15":{"0":5.7,"1":4.4,"2":1.5,"3":0.4,"4":"Iris-setosa"},"16":{"0":5.4,"1":3.9,"2":1.3,"3":0.4,"4":"Iris-setosa"},"17":{"0":5.1,"1":3.5,"2":1.4,"3":0.3
# ...

# %%
pd.read_json(StringIO(jdata),orient='index')
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data = [{"employee_name": "Sushil", "email": "sushil@gamil.com","profile": {"title1":"AIML","title2":"Engineer"}}]

# %%
type(data)
# Out:
# list

# %%
pd.json_normalize(data)   #This is split the nested data inside the dictionary
# Out:
#   employee_name             email profile.title1 profile.title2
# 0        Sushil  sushil@gamil.com           AIML       Engineer

# %%
data = [
    {
        "state": "Utter Pradesh",
        "shortname": "UP",
        "info": {"Governor":"Rick Scott"},
        "counties": [
            {"name": "Dade", "population":1223},
            {"name": "Broward","population":2345},
            {"name": "Palm Beach","population":57987},
        ],
    },
    {
        "state": "Bangladesh",
        "shortname": "Bl",
        "info": {"Governor":"MileStone"},
        "counties": [
            {"name": "Goa Beach", "population":1523},
            {"name": "Tajmahal","population":835},
            {"name": "India Gate","population":5857},
        ],
    },
]

# %%
pd.json_normalize(data)
# Out:
#            state shortname                                          countries  \
# 0  Utter Pradesh        UP  [{'name': 'Dade', 'Population': 1223}, {'name'...
# 1     Bangladesh        Bl  [{'name': 'Austrilia', 'Population': 1523}, {'...
#
#   info.Governor
# 0    Rick Scott
# 1     MileStone

# %%
pd.json_normalize(data, "counties", ["state","shortname"])
# Out:
#          name  population          state shortname
# 0        Dade        1223  Utter Pradesh        UP
# 1     Broward        2345  Utter Pradesh        UP
# 2  Palm Beach       57987  Utter Pradesh        UP
# 3   Goa Beach        1523     Bangladesh        Bl
# 4    Tajmahal         835     Bangladesh        Bl
# 5  India Gate        5857     Bangladesh        Bl

# %%
import pandas as pd

# %%
type(data)
# Out:
# list

# %%
pd
# Out:
#          name  population          state shortname
# 0        Dade        1223  Utter Pradesh        UP
# 1     Broward        2345  Utter Pradesh        UP
# 2  Palm Beach       57987  Utter Pradesh        UP
# 3   Goa Beach        1523     Bangladesh        Bl
# 4    Tajmahal         835     Bangladesh        Bl
# 5  India Gate        5857     Bangladesh        Bl
