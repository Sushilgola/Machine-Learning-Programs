# %%
import pandas as pd

# %%
dic = {'Name':['Sushil','Himanshu','Honey'],
      'Age':[21,18,24],
      'City':['Aligarh','Aligarh']}

# %%
df = pd.DataFrame([dic])

# %%
df
# Out:
#                         Name           Age                City
# 0  [Sushil, Himanshu, Honey]  [21, 18, 24]  [Aligarh, Aligarh]

# %%
df = pd.DataFrame({'Name':['Sushil','Himanshu','Honey'],
      'Age':[21,18,24],
      'City':['Aligarh','Aligarh','Gaziabad']})

# %%
df
# Out:
#        Name  Age      City
# 0    Sushil   21   Aligarh
# 1  Himanshu   18   Aligarh
# 2     Honey   24  Gaziabad

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# To see Basic Info Of DataSet
df.shape
# Out:
# (8807, 12)

# %%
df.head()['title']
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
cast_col = df.head()['cast']
type(cast_col)
# Out:
# pandas.core.series.Series

# %%
# columns = (df['title'],df['director'])
df2 = pd.DataFrame({df['title'],df['director']})
df2.head()
# Out:
#                           0              1                2     \
# title     Dick Johnson Is Dead  Blood & Water        Ganglands
# director       Kirsten Johnson            NaN  Julien Leclercq
#
#                            3             4              5     \
# title     Jailbirds New Orleans  Kota Factory  Midnight Mass
# director                    NaN           NaN  Mike Flanagan
#
#                                       6             7     \
# title     My Little Pony: A New Generation       Sankofa
# director     Robert Cullen, José Luis Ucha  Haile Gerima
#
#                                    8               9     ...       8797  \
# title     The Great British Baking Show    The Starling  ...  Zak Storm
# director                Andy Devonshire  Theodore Melfi  ...        NaN
#
#                              8798            8799                8800  \
# title                    Zed Plus           Zenda  Zindagi Gulzar Hai
# ...

# %%
df.head()['release_year']>2020
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# Name: release_year, dtype: bool

# %%
df1 = pd.read_csv('homeprices.csv')
df1
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df1['place'] = ['rular', 'town','village','city','town','city']

# %%
df1['area'] = [2600,3000,3200,3600,4000,4100]

# %%
df1
# Out:
#    area  bedrooms  age   price    place
# 0  2600       3.0   20  550000    rular
# 1  3000       4.0   15  565000     town
# 2  3200       NaN   18  610000  village
# 3  3600       3.0   30  595000     city
# 4  4000       5.0    8  760000     town
# 5  4100       6.0    8  810000     city

# %%
df1.drop('place', axis=1)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df1.rename(columns={'area': 'Area'}, inplace=True)

# %%
df1
# Out:
#    Area  bedrooms  age   price    place
# 0  2600       3.0   20  550000    rular
# 1  3000       4.0   15  565000     town
# 2  3200       NaN   18  610000  village
# 3  3600       3.0   30  595000     city
# 4  4000       5.0    8  760000     town
# 5  4100       6.0    8  810000     city

# %%
empty_val = df1['bedrooms'].isnull().sum()
# empty_val
# Out:
# np.int64(1)

# %%
#Fill Missing values

mean_val = df1['bedrooms'].mean()
mean_val
# Out:
# np.float64(3.5)

# %%
df1['bedrooms'] = df1['bedrooms'].fillna(mean_val)

# %%
df1
# Out:
#    Area  bedrooms  age   price    place
# 0  2600       3.0   20  550000    rular
# 1  3000       4.0   15  565000     town
# 2  3200       0.0   18  610000  village
# 3  3600       3.0   30  595000     city
# 4  4000       5.0    8  760000     town
# 5  4100       6.0    8  810000     city

# %%
#Drop Missing Rows
df2 = pd.read_csv('homeprices.csv')
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
is_null = df2['bedrooms'].isnull()
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df2.drop(df2[df2['bedrooms'].isnull()].index, axis=0, inplace=True)

# %%
df2[df2['bedrooms'].isnull()].index
# Out:
# Index([], dtype='int64')

# %%
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
#Sorting (Ascending and Descending)
new_df2 = df2.sort_values('area', ascending=True)

# %%
new_df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df2.sort_values('price', ascending=False)
# Out:
#    area  bedrooms  age   price
# 5  4100       6.0    8  810000
# 4  4000       5.0    8  760000
# 3  3600       3.0   30  595000
# 1  3000       4.0   15  565000
# 0  2600       3.0   20  550000

# %%
# Count the Columns Data
# ind = df2[df2['price'].notnull()].index

df2.count()
# Out:
# area        5
# bedrooms    5
# age         5
# price       5
# dtype: int64

# %%
# Apply Function  add some numbers in table data

def add_nums(n):
    new_df = df2['price']+n
    return new_df

# %%
add_nums(100)
# Out:
# 0    550100
# 1    565100
# 3    595100
# 4    760100
# 5    810100
# Name: price, dtype: int64

# %%
# GroupBy
# Department ke basis par average salary nikaalo.  (Find Mean)

av_sal = df2['price'].mean()

# %%
print('Average Price: ',av_sal)
# Out:
# Average Price:  656000.0

# %%
# Merge DataFrames 
#  Merge Two DataFrame in one Frame
df1 = pd.read_csv('homeprices1.csv')

# %%
df2 = pd.read_csv('hiring.csv')

# %%
pd.merge(df1,df2, on='index')            # For Merge th
# Out:
#    area   price  index experience  interview_score(out of 10)  salary($)
# 0  2600  550000      1       four                           9      50000
# 1  3000  565000      2      eight                           6      45000
# 2  3200  610000      3       five                           7      60000
# 3  3600  680000      4        two                          10      65000
# 4  4000  725000      5      seven                           6      70000

# %%
# Concatenate ->
# Do DataFrames ko vertically ya horizontally join karo.
