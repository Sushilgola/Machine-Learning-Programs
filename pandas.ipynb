# %%
import pandas as pd

# %%
df = pd.read_excel('weather_data_20days.xlsx')

# %%
df.head()
# Out:
#     date_ist  time_ist     location      lat     lon  temp_c  humidity  \
# 0 2025-01-01  00:00:00  Anand Vihar  28.6469  77.316     8.1       100
# 1 2025-01-01  01:00:00  Anand Vihar  28.6469  77.316     7.7       100
# 2 2025-01-01  02:00:00  Anand Vihar  28.6469  77.316     7.5       100
# 3 2025-01-01  03:00:00  Anand Vihar  28.6469  77.316     7.8        99
# 4 2025-01-01  04:00:00  Anand Vihar  28.6469  77.316     7.3       100
#
#    pressure_mb  windspeed_kph condition_text description  aqi_index  pm2_5  \
# 0        995.4            2.9   Mainly clear  WMO Code 1        197  185.8
# 1        994.7            3.2       Overcast  WMO Code 3        198  174.6
# 2        994.3            4.5       Overcast  WMO Code 3        199  164.4
# 3        994.1            6.0       Overcast  WMO Code 3        200  156.5
# 4        993.8            6.8       Overcast  WMO Code 3        200  149.5
#
#     pm10    co   no2
# 0  188.6  1907  56.7
# 1  177.4  1669  44.8
# ...

# %%
df['location']
# Out:
# 0     Anand Vihar
# 1     Anand Vihar
# 2     Anand Vihar
# 3     Anand Vihar
# 4     Anand Vihar
# 5     Anand Vihar
# 6     Anand Vihar
# 7     Anand Vihar
# 8     Anand Vihar
# 9     Anand Vihar
# 10    Anand Vihar
# 11    Anand Vihar
# 12    Anand Vihar
# 13    Anand Vihar
# 14    Anand Vihar
# 15    Anand Vihar
# 16    Anand Vihar
# 17    Anand Vihar
# 18    Anand Vihar
# Name: location, dtype: object

# %%
df['temp_c'].max()

# %%
df.describe()
# Out:
#                   date_ist           lat           lon     temp_c    humidity  \
# count                   19  1.900000e+01  1.900000e+01  19.000000   19.000000
# mean   2025-01-01 00:00:00  2.864690e+01  7.731600e+01  11.142105   89.157895
# min    2025-01-01 00:00:00  2.864690e+01  7.731600e+01   7.300000   70.000000
# 25%    2025-01-01 00:00:00  2.864690e+01  7.731600e+01   7.900000   78.500000
# 50%    2025-01-01 00:00:00  2.864690e+01  7.731600e+01   9.400000   97.000000
# 75%    2025-01-01 00:00:00  2.864690e+01  7.731600e+01  14.750000   99.000000
# max    2025-01-01 00:00:00  2.864690e+01  7.731600e+01  16.900000  100.000000
# std                    NaN  3.650066e-15  1.460027e-14   3.695691   11.861531
#
#        pressure_mb  windspeed_kph   aqi_index       pm2_5        pm10  \
# count    19.000000      19.000000   19.000000   19.000000   19.000000
# mean    994.310526       5.794737  200.210526  138.600000  141.184211
# ...

# %%
df[df.temp_c==14.6]
# Out:
#      date_ist  time_ist     location      lat     lon  temp_c  humidity  \
# 12 2025-01-01  12:00:00  Anand Vihar  28.6469  77.316    14.6        77
#
#     pressure_mb  windspeed_kph condition_text description  aqi_index  pm2_5  \
# 12        994.7            6.3      Clear sky  WMO Code 0        200  115.5
#
#      pm10    co   no2
# 12  118.3  1079  15.4

# %%
df[df.temp_c==df['temp_c'].max()]
# Out:
#      date_ist  time_ist     location      lat     lon  temp_c  humidity  \
# 15 2025-01-01  15:00:00  Anand Vihar  28.6469  77.316    16.9        70
#
#     pressure_mb  windspeed_kph condition_text description  aqi_index  pm2_5  \
# 15        992.3            6.9      Clear sky  WMO Code 0        201   99.4
#
#      pm10    co   no2
# 15  102.7  1291  21.0

# %%
df[['date_ist','temp_c','location']][df.temp_c == df['temp_c'].max()]
# Out:
#      date_ist  temp_c     location
# 15 2025-01-01    16.9  Anand Vihar

# %%
df.set_index('date_ist', inplace=True)

# %%
df.loc['2025-01-01']
# Out:
#             time_ist     location      lat     lon  temp_c  humidity  \
# date_ist
# 2025-01-01  00:00:00  Anand Vihar  28.6469  77.316     8.1       100
# 2025-01-01  01:00:00  Anand Vihar  28.6469  77.316     7.7       100
# 2025-01-01  02:00:00  Anand Vihar  28.6469  77.316     7.5       100
# 2025-01-01  03:00:00  Anand Vihar  28.6469  77.316     7.8        99
# 2025-01-01  04:00:00  Anand Vihar  28.6469  77.316     7.3       100
# 2025-01-01  05:00:00  Anand Vihar  28.6469  77.316     7.6        99
# 2025-01-01  06:00:00  Anand Vihar  28.6469  77.316     8.1        99
# 2025-01-01  07:00:00  Anand Vihar  28.6469  77.316     8.0        99
# 2025-01-01  08:00:00  Anand Vihar  28.6469  77.316     8.4        99
# 2025-01-01  09:00:00  Anand Vihar  28.6469  77.316     9.4        97
# 2025-01-01  10:00:00  Anand Vihar  28.6469  77.316    11.3        89
# 2025-01-01  11:00:00  Anand Vihar  28.6469  77.316    13.1        81
# ...

# %%
df.set_index('condition_text', inplace=True)
df
# Out:
#                    location      lat     lon  temp_c  humidity  pressure_mb  \
# condition_text
# Mainly clear    Anand Vihar  28.6469  77.316     8.1       100        995.4
# Overcast        Anand Vihar  28.6469  77.316     7.7       100        994.7
# Overcast        Anand Vihar  28.6469  77.316     7.5       100        994.3
# Overcast        Anand Vihar  28.6469  77.316     7.8        99        994.1
# Overcast        Anand Vihar  28.6469  77.316     7.3       100        993.8
# Overcast        Anand Vihar  28.6469  77.316     7.6        99        993.9
# Overcast        Anand Vihar  28.6469  77.316     8.1        99        994.7
# Overcast        Anand Vihar  28.6469  77.316     8.0        99        995.2
# Overcast        Anand Vihar  28.6469  77.316     8.4        99        995.7
# Overcast        Anand Vihar  28.6469  77.316     9.4        97        996.3
# Overcast        Anand Vihar  28.6469  77.316    11.3        89        996.3
# ...

# %%
df.loc['Clear sky']
# Out:
#                    location      lat     lon  temp_c  humidity  pressure_mb  \
# condition_text
# Clear sky       Anand Vihar  28.6469  77.316    14.6        77        994.7
# Clear sky       Anand Vihar  28.6469  77.316    15.8        73        993.5
# Clear sky       Anand Vihar  28.6469  77.316    16.5        72        992.6
# Clear sky       Anand Vihar  28.6469  77.316    16.9        70        992.3
# Clear sky       Anand Vihar  28.6469  77.316    16.5        72        992.2
# Clear sky       Anand Vihar  28.6469  77.316    14.9        80        992.2
# Clear sky       Anand Vihar  28.6469  77.316    12.2        88        994.1
#
#                 windspeed_kph description  aqi_index  pm2_5   pm10    co   no2
# condition_text
# Clear sky                 6.3  WMO Code 0        200  115.5  118.3  1079  15.4
# Clear sky                 6.2  WMO Code 0        200  108.7  111.8  1037  13.1
# Clear sky                 6.3  WMO Code 0        201  103.6  106.6  1085  14.1
# ...
